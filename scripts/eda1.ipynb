# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

filepaths = {
    "abonado": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/abonado.csv",
    "caudales": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/caudales.csv",
    "cliente": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/cliente.csv",
    "clima": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/clima.csv",
    "contador": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/contador.csv",
    "gis": "C:/Users/rbelt/Desktop/uni/Datathon/datasets/gis.csv",
}

abonado_df = pd.read_csv(filepaths["abonado"])
caudales_df = pd.read_csv(filepaths["caudales"])
cliente_df = pd.read_csv(filepaths["cliente"])
clima_df = pd.read_csv(filepaths["clima"])
contador_df = pd.read_csv(filepaths["contador"])
gis_df = pd.read_csv(filepaths["gis"])

print("All datasets read")
# Out:
# All datasets read

# %%
abonado_df.describe()
# Out:
#        COD_SUMINISTRO  NUM_VIVIENDAS  NUM_PERSONAS
# count    7.053000e+03         6703.0   6451.000000
# mean     1.430315e+09            1.0      2.863587
# std      7.424922e+09            0.0      0.504239
# min      9.793790e+05            1.0      1.000000
# 25%      9.891500e+05            1.0      3.000000
# 50%      9.972730e+05            1.0      3.000000
# 75%      9.993690e+05            1.0      3.000000
# max      4.000010e+10            1.0      3.000000

# %%
caudales_df.describe()
# Out:
#           INF_Value   Sector_Neta
# count  1.024227e+06  1.024227e+06
# mean   1.317640e+05  2.223161e+07
# std    3.352503e+05  2.641363e+05
# min    0.000000e+00  2.211000e+07
# 25%    2.560000e+00  2.212000e+07
# 50%    9.520000e+00  2.212200e+07
# 75%    1.600000e+02  2.213210e+07
# max    2.555568e+07  2.288001e+07

# %%
cliente_df.describe()
# Out:
#        COD_SUMINISTRO
# count    7.053000e+03
# mean     1.430315e+09
# std      7.424922e+09
# min      9.793790e+05
# 25%      9.891500e+05
# 50%      9.972730e+05
# 75%      9.993690e+05
# max      4.000010e+10

# %%
clima_df.describe()
# Out:
#               wdir         temp         maxt   visibility         wspd  \
# count  2184.000000  2185.000000  2185.000000  2185.000000  2185.000000
# mean    180.988164    17.492586    23.303616    12.444256    19.314005
# std      67.401268     7.307811     8.102205     2.001818     7.464505
# min      23.170000    -1.400000     1.700000     2.500000     3.600000
# 25%     127.540000    11.600000    16.600000    11.400000    13.900000
# 50%     181.960000    16.900000    22.500000    12.400000    18.600000
# 75%     242.255000    23.600000    29.800000    13.900000    24.100000
# max     315.960000    34.100000    43.700000    20.000000    86.100000
#
#        solarenergy   heatindex   cloudcover         mint      datetime  ...  \
# count  1163.000000  820.000000  2048.000000  2185.000000  2.187000e+03  ...
# mean     15.807223   31.592683    39.062402    11.501876  1.640909e+12  ...
# std       7.679490    3.589970    23.508103     6.655598  1.818652e+10  ...
# ...

# %%
contador_df.describe()
# Out:
#            CALIBRE
# count  6343.000000
# mean     13.223081
# std       2.868102
# min       0.000000
# 25%      13.000000
# 50%      13.000000
# 75%      13.000000
# max      80.000000

# %%
gis_df.describe()
# Out:
#                code    parentCode
# count  1.500000e+01  1.400000e+01
# mean   2.212420e+07  2.211843e+07
# std    9.906852e+03  1.289433e+04
# min    2.210000e+07  2.210000e+07
# 25%    2.212050e+07  2.210500e+07
# 50%    2.212290e+07  2.212100e+07
# 75%    2.213150e+07  2.213000e+07
# max    2.213900e+07  2.213200e+07
